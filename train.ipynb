# %%
import warnings
import pickle
warnings.filterwarnings("ignore")
from time import strftime, localtime
from core.util import *

g_hash = strftime("%Y_%m_%d_%H_%M_%S", localtime())

myLog('ID_hash=%s'%g_hash)
with open('name.pkl', 'wb') as f:
    pickle.dump({'name':g_hash, 
                 'root':'/mnt/yifan/gic4d4/', 
                 'data_root': '/mnt/yifan/data/'#'/home/alex/Documents/',
                 }, f)

def load_hash(key):
    with open('name.pkl', 'rb') as f:
        d = pickle.load(f)
    return d[key]

# %%
from core.rdvq1ac import VQ
from core.util.evaluate import *
from core.data import *
import numpy as np
from core.util import *
import warnings
warnings.filterwarnings("ignore")
from core.OneGridSC import OneGridSC, load_color

root = load_hash('root')
g_hash = load_hash('name')
fit32 = file_exist('./G5_'+g_hash+'_modelr.model')

g3VQp = VQ(n_clusters_list=[[2048],[8,2048],
                            [4,4,8,2048]], 
            win_list=[2,2,2], 
            n_dim_list=[[4],
                        [3,4],
                        [1,2,3,4]],Lagrange_multip=30000)
g3VQq = VQ(n_clusters_list=[[2048],
                            [4,8,2048]], 
            win_list=[4,2], 
            n_dim_list=[[16],
                        [1, 3,4]], 
            Lagrange_multip=30000)
g3VQr = VQ(n_clusters_list=[[128],
                            [8,128]], 
            win_list=[4,2], 
            n_dim_list=[[16],
                        [2,4]], 
            Lagrange_multip=30000)

g5VQp = VQ(n_clusters_list=[[2048],
                            [2048],
                            [4,2048],
                            [4,2048],
                            [4,8,2048]], 
            win_list=[2,2,2,2,2], 
            n_dim_list=[[4],
                        [4],
                        [3,4],
                        [3,4],
                        [2,3,4]], 
          Lagrange_multip=30000)
g5VQq = VQ(n_clusters_list=[[2048],
                            [2048],
                            [2048],
                            [2048],      
                            [2048]], 
            win_list=[2,2,2,2,2], 
            n_dim_list=[[4],
                        [4],
                        [4],
                        [4],
                        [4]], 
            enable_skip={},
          Lagrange_multip=30000)
g5VQr = VQ(n_clusters_list=[[64],
                            [64],
                            [4,128]], 
            win_list=[8,2,2], 
            n_dim_list=[[64],
                        [4],
                        [2,4]], 
          Lagrange_multip=30000)

if fit32 == True:
    Y8, Y32 = load(Rtype='small', ct=[190,600], size=None)
    color = load_color(root, Y32)

    g3 = OneGridSC(grid=3, model_hash=g_hash, model_p=g3VQp, model_q=g3VQq, model_r=g3VQr)
    g3.fit(np.zeros_like(Y8), Y8, color)    
    iY8 = g3.predict(np.zeros_like(Y8), Y8, color,loadonce=False)
    g3, Y8 = [], []

    g5 = OneGridSC(grid=5, model_hash=g_hash, model_p=g5VQp, model_q=g5VQq, model_r=g5VQr)
    g5.fit(iY8, Y32, color)

# %reset -f

# %%
from core.rdvq1ac import VQ
from core.util.evaluate import *
from core.data import *
import numpy as np
from core.util import *
import warnings
warnings.filterwarnings("ignore")
from core.OneGridSC import OneGridSC, load_color

root = load_hash('root')
g_hash = load_hash('name')
fit64 = file_exist('./G6_'+g_hash+'_modelr.model')
\
g6VQp = VQ(n_clusters_list=[[2048],[2048],
                            [2048],
                            [4,2048],
                            [4,2048],
                            [4,8,2048]], 
            win_list=[2,2,2,2,2,2], 
            n_dim_list=[[4],
                        [4],
                        [4],
                        [3,4],
                        [3,4],
                        [2,3,4]], 
          Lagrange_multip=30000)
g6VQq = VQ(n_clusters_list=[[2048],[2048],
                            [2048],
                            [2048],
                            [2048],      
                            [2048]], 
            win_list=[2,2,2,2,2,2], 
            n_dim_list=[[4],[4],
                        [4],
                        [4],
                        [4],
                        [4]], 
          Lagrange_multip=30000)
g6VQr = VQ(n_clusters_list=[[64],[64],
                            [64],
                            [8,128]], 
            win_list=[4,4,2,2], 
            n_dim_list=[[64],[64],
                        [4],
                        [2,4]], 
          Lagrange_multip=30000)

if fit64 == True:
    tmp = load(Rtype='train', ct=[1,3000], size=[256,128,64,32,8])
    Y256, Y64, Y32, Y8 = tmp[0], tmp[2],tmp[3],tmp[4]
    color = load_color(root, Y256)
    Y256, Y128, tmp = [], [], None

    g3 = OneGridSC(grid=3, model_hash=g_hash)
    iY8 = g3.predict(np.zeros_like(Y8), Y8, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g3, Y8 = None, None

    g5 = OneGridSC(grid=5, model_hash=g_hash)
    iY32 = g5.predict(iY8, Y32, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g5, Y32, iY8 = None, None, None

    g6 = OneGridSC(grid=6, model_hash=g_hash, model_p=g6VQp, model_q=g6VQq, model_r=g6VQr)
    g6.fit(iY32, Y64, color)
# %reset -f

# %%
from core.rdvq1ac import VQ
from core.util.evaluate import *
from core.data import *
import numpy as np
from core.util import *
import warnings
warnings.filterwarnings("ignore")
from core.OneGridSC import OneGridSC, load_color

root = load_hash('root')
g_hash = load_hash('name')
fit128 = file_exist('./G7_'+g_hash+'_modelr.model')

g7VQp = VQ(n_clusters_list=[[16,2048], 
                            [16,2048], 
                            [16,2048], 
                            [16, 2048], 
                            [16, 2048], 
                            [16, 2048], 
                            [16, 2048]], 
            win_list=[2, 2, 2, 2, 2, 2, 2], 
            n_dim_list=[[4, 48],
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12]], 
            transform_split=2,
          Lagrange_multip=30000)
g7VQq = VQ(n_clusters_list=[[512], 
                            [512], 
                            [512], 
                            [512], 
                            [512]], 
            win_list=[4,4, 2, 2, 2], 
            n_dim_list=[[64], [16], [16], [4], [4]], 
          Lagrange_multip=30000)
g7VQr = VQ(n_clusters_list=[[4], [4], [4], [8]], 
            win_list=[8, 4, 2, 2], 
            n_dim_list=[[256], [16], [4], [4]], 
          Lagrange_multip=30000)



if fit128 == True:    
    tmp = load(Rtype='train', ct=[2,2000], size=[256,128,64,32,8])
    Y256, Y128,Y64, Y32, Y8 = tmp[0],tmp[1], tmp[2],tmp[3],tmp[4]
    color = load_color(root, Y256)
    Y256, tmp =[], None
    
    g3 = OneGridSC(grid=3, model_hash=g_hash)
    iY8 = g3.predict(np.zeros_like(Y8), Y8, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g3, Y8 = None, None

    g5 = OneGridSC(grid=5, model_hash=g_hash)
    iY32 = g5.predict(iY8, Y32, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g5, Y32, iY8 = None, None, None

    g6 = OneGridSC(grid=6, model_hash=g_hash)
    iY64 = g6.predict(iY32, Y64, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g6, Y64, iY32 = None, None, None
    
    g7 = OneGridSC(grid=7, model_hash=g_hash, model_p=g7VQp, model_q=g7VQq, model_r=g7VQr)
    g7.fit(iY64, Y128, color)
# %reset -f

# %%
from core.rdvq1ac import VQ
from core.util.evaluate import *
from core.data import *
import numpy as np
from core.util import *
import warnings
warnings.filterwarnings("ignore")
from core.OneGridSC import OneGridSC, load_color

root = load_hash('root')
g_hash = load_hash('name')
fit256 = file_exist('./G8_'+g_hash+'b_modelr'+'.model')

g8VQp = VQ(n_clusters_list=[[128,1024], 
                            [128,1024], 
                            [128,1024], 
                            [128,1024], 
                            [128, 1024], 
                            [128, 1024], 
                            [128, 1024], 
                            [128, 1024]], 
            win_list=[2, 2, 2, 2, 2, 2, 2, 2], 
            n_dim_list=[[4, 48],
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12], 
                        [4, 12]], 
            transform_split=2,
          Lagrange_multip=30000)
g8VQq = VQ(n_clusters_list=[[512], 
                            [512], 
                            [512], 
                            [512], 
                            [512]], 
            win_list=[4,4, 4, 2, 2], 
            n_dim_list=[[64], [16], [16], [4], [4]], 
          Lagrange_multip=30000)
g8VQr = VQ(n_clusters_list=[[4], [4], [4], [8]], 
            win_list=[16, 4, 2, 2], 
            n_dim_list=[[256], [16], [4], [4]], 
          Lagrange_multip=30000)

if fit256 == True:  
    tmp = load(Rtype='train', ct=[3,2000], size=[256,128,64,32,8])
    Y256,Y128,Y64, Y32, Y8 = tmp[0], tmp[1], tmp[2],tmp[3],tmp[4]
    color = load_color(root, Y256)
    tmp = None

    g3 = OneGridSC(grid=3, model_hash=g_hash)
    iY8 = g3.predict(np.zeros_like(Y8), Y8, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g3, Y8 = None, None
    
    g5 = OneGridSC(grid=5, model_hash=g_hash)
    iY32 = g5.predict(iY8, Y32, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g5, Y32, iY8 = None, None, None
    
    g6 = OneGridSC(grid=6, model_hash=g_hash)
    iY64 = g6.predict(iY32, Y64, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g6, Y64, iY32 = None, None, None

    g7 = OneGridSC(grid=7, model_hash=g_hash)
    iY128 = g7.predict(iY64, Y128, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g7, Y128, iY64 = None, None, None

    g8 = OneGridSC(grid=8, model_hash=g_hash+'b', model_p=g8VQp, model_q=g8VQq, model_r=g8VQr)
    g8.fit(iY128, Y256, color)

# %reset -f

# %%
    
from core.rdvq1ac import VQ
from core.rdvq1ac_noT import VQ_noT
from core.util.evaluate import *
from core.data import *
import numpy as np
from core.util import *
import warnings
warnings.filterwarnings("ignore")
from core.OneGridSC import OneGridSC, load_color
from core.OneGridSCwhole import OneGridSCwhole

root = load_hash('root')
g_hash = load_hash('name')
fit256_2 = file_exist('./G8_'+g_hash+'2c.model')

g8VQp2 = VQ_noT(n_clusters_list=[[1024]], 
            win_list=[2], 
            n_dim_list=[[32]], 
            enable_skip={},
            transform_split=1,
          Lagrange_multip=30000)

if fit256_2 == True:    
    tmp = load(Rtype='train', ct=[3,2000], size=[256,128,64,32,8])
    Y256,Y128,Y64, Y32, Y8 = tmp[0], tmp[1], tmp[2],tmp[3],tmp[4]
    color = load_color(root, Y256)
    tmp = None

    g3 = OneGridSC(grid=3, model_hash=g_hash)
    iY8 = g3.predict(np.zeros_like(Y8), Y8, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g3, Y8 = None, None

    g5 = OneGridSC(grid=5, model_hash=g_hash)
    iY32 = g5.predict(iY8, Y32, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g5, Y32, iY8 = None, None, None

    g6 = OneGridSC(grid=6, model_hash=g_hash)
    iY64 = g6.predict(iY32, Y64, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g6, Y64, iY32 = None, None, None

    g7 = OneGridSC(grid=7, model_hash=g_hash)
    iY128 = g7.predict(iY64, Y128, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g7, Y128, iY64 = None, None, None

    g8 = OneGridSC(grid=8, model_hash=g_hash+'b')
    iY256 = g8.predict(iY128, Y256, color, new_lambda=[20000, 20000, 20000],loadonce=False)
    g8, iY128 = None, None

    g82 = OneGridSCwhole(grid=8, model_hash=g_hash+'2c', model_p=g8VQp2)
    g82.fit(iY256, Y256)
    
# %reset -f

# %%
from core.rdvq1ac import VQ
from core.rdvq1ac_noT import VQ_noT
from core.util.evaluate import *
from core.data import *
import numpy as np
from core.util import *
import warnings
warnings.filterwarnings("ignore")
from core.OneGridSC import OneGridSC, load_color
from core.OneGridSCwhole import OneGridSCwhole

root = load_hash('root')
g_hash = load_hash('name')
fit256_1 = file_exist('./G8_'+g_hash+'1c.model')

g8VQp1 = VQ_noT(n_clusters_list=[[64]], 
            win_list=[1], 
            n_dim_list=[[4]], 
            transform_split=1,
          Lagrange_multip=30000)

if fit256_1 == True:    
    tmp = load(Rtype='train', ct=[3,2000], size=[256,128,64,32,8])
    Y256,Y128,Y64, Y32, Y8 = tmp[0], tmp[1], tmp[2],tmp[3],tmp[4]
    color = load_color(root, Y256)
    tmp = None

    g3 = OneGridSC(grid=3, model_hash=g_hash)
    iY8 = g3.predict(np.zeros_like(Y8), Y8, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g3, Y8 = None, None

    g5 = OneGridSC(grid=5, model_hash=g_hash)
    iY32 = g5.predict(iY8, Y32, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g5, Y32, iY8 = None, None, None

    g6 = OneGridSC(grid=6, model_hash=g_hash)
    iY64 = g6.predict(iY32, Y64, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g6, Y64, iY32 = None, None, None

    g7 = OneGridSC(grid=7, model_hash=g_hash)
    iY128 = g7.predict(iY64, Y128, color, new_lambda=[10000, 10000, 10000],loadonce=False)
    g7, Y128, iY64 = None, None, None

    g8 = OneGridSC(grid=8, model_hash=g_hash+'b')    
    iY256 = g8.predict(iY128, Y256, color, new_lambda=[20000, 20000, 20000],loadonce=False)
    g8, iY128 = None, None

    g82 = OneGridSCwhole(grid=8, model_hash=g_hash+'2c')
    iY256 = g82.predict(iY256, Y256)
    g82=None

    g81 = OneGridSCwhole(grid=8, model_hash=g_hash+'1c', model_p=g8VQp1)
    g81.fit(iY256, Y256)

# %reset -f
